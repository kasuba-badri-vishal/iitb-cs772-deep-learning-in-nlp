# %%
# !pip install git+https://github.com/huggingface/transformers -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 67.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 25.4 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline, AutoTokenizer, AutoModelForSeq2SeqLM
import torch

# %%
#set the device
device = torch.cuda.current_device() if torch.cuda.is_available() else -1

#load the model
model_name = 'facebook/nllb-200-distilled-600M'
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

#load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, src_lang="eng_Latn", tgt_lang="hin_Deva")

#create pipeline object
translator = pipeline('translation', model=model, tokenizer=tokenizer,src_lang="eng_Latn", tgt_lang="hin_Deva",device=device)
# Out:
# ...
# अच्छी तरह से बाकी भाषा के लिए एक मॉडल है

# %%
#get the translated sentence
summary = translator("We show the spectra of cosmic rays for all three models, in the local plasma frame.<n>All three model afterglows use an upstream ambient magnetic field Bp = 3 mG.<n>This is orders of magnitude higher than the typical value of 3 1G assumed for the Milky Way.",max_length=128)

#display the translated sentence
print(summary[0]['translation_text'])
# output : Rahul was given the award of the Man of the Match to save his grand bat and territory.
# Out:
# हम स्थानीय प्लाज्मा फ्रेम में तीनों मॉडल के लिए ब्रह्मांडीय किरणों के स्पेक्ट्रम दिखाते हैं। सभी तीन मॉडल के बाद के ग्लोब एक अपस्ट्रीम परिवेश चुंबकीय क्षेत्र Bp = 3 mG का उपयोग करते हैं। यह आकाशगंगा के लिए 3 1G के सामान्य मूल्य से अधिक परिमाण का आदेश है।
